# %% [markdown]
# # Post-processing CLAMP Output files

# %% [markdown]
# We took the outputs from CLAMP (Clinical Language Annotation, Modeling, and Processing) and post-processed the output by 1) cleaning the data, 2) processing the different section headings, 3) formatting it for input into our models

# %%
from google.cloud import storage
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Extract pid/nid from title and create column

# %% [markdown]
# We are extracting the patient ID (pid) and note ID (nid) to concatenate the notes per patient.

# %%
def extract_ids(file_name, df):
    pid = re.search("(?<=pid)[0-9]*(?=-nid)", file_name).group()
    nid = re.search("(?<=nid)[0-9]*(?=\.txt)", file_name).group()
    # Add column
    df.insert(loc = 0, column = 'PID', value = pid)
    df.insert(loc = 1, column = 'NID', value = nid)
    return df

# %% [markdown]
# ## Processing Section Headers
# - Select the first detection of a section in the notes and remove duplicates.
# - Assign all the terms that follow each section heading into that section (add new column for dataframe)
# - Combine specific section labels into categories

# %%
# Processes the dataframe to place names entities into sections
def process_section_headers(df):
    section_specific_list = ['ALLERGY','AP','ASSESSMENT','ATTESTATION','CALL','CHIEF_COMPLAINT','CONSENT','CURRENT_MEDICATIONS',
                             'ENCOUNTER_DIAGNOSES','EXAM','EYE_EXAM','EYE_MEDICATIONS','FAMILY_HX','HPI','INSTRUCTION','INTERPRETATION',
                             'MEDICATION','OCULAR_HISTORY','PAST_SURGICAL_HISTORY','PLAN','PMH','PROBLEM_LIST','RISK','ROS','SLE',
                             'SOCIAL_HX','VISUAL_ACUITY']
    section_category_list = ["AP","INSTRUCTION","CC/HPI","HISTORY","ALLERGY","EXAM","ROS","MEDICATION",
                         "FAM_SOC_HX","INSTRUCTION","ATTESTATION","CONSENT","INTERPRETATION"]
    specific_to_category_dict = {'ALLERGY':'ALLERGY','AP':'AP','ASSESSMENT':'AP','ATTESTATION':'ATTESTATION','CALL':'INSTRUCTION',
                                 'CHIEF_COMPLAINT':'CC/HPI','CONSENT':'CONSENT','CURRENT_MEDICATIONS':'MEDICATION',
                                 'ENCOUNTER_DIAGNOSES':'AP','EXAM':'EXAM','EYE_EXAM':'EXAM','EYE_MEDICATIONS':'MEDICATION',
                                 'FAMILY_HX':'FAM_SOC_HX','HPI':'CC/HPI','INSTRUCTION':'INSTRUCTION','INTERPRETATION':'INTERPRETATION',
                                 'MEDICATION':'MEDICATION','OCULAR_HISTORY':'HISTORY','PAST_SURGICAL_HISTORY':'HISTORY','PLAN':'AP',
                                 'PMH':'HISTORY','PROBLEM_LIST':'HISTORY','RISK':'CONSENT','ROS':'ROS','SLE':'EXAM',
                                 'SOCIAL_HX':'FAM_SOC_HX','VISUAL_ACUITY':'EXAM'}
    
    # Create new columns in the dataframe
    df['Section_Header'] = ''
    df['Section_Category'] = ''

    #Isolate section header entities
    df_headers = df.loc[df['Semantic'].isin(section_specific_list)]

    # Remove duplicated section headers
    df_headers_nodup = df_headers.drop_duplicates(subset='Semantic', keep='first')
    df_headers_nodup = df_headers_nodup.reset_index(drop=True)
#     print("---------------- Section headers: --------------------")
#     display(df_headers_nodup)

    #if no section headers exist
    if (df_headers_nodup.shape[0] <= 0):
        return df
    
    #Assign entities that follow each section heading into that section
    header_index = 0
    for index, row in df.iterrows():
        curr_header = df_headers_nodup.iloc[header_index]
       
        # 0 to n-1 sections
        if (header_index < df_headers_nodup.shape[0]-1):
            next_header = df_headers_nodup.iloc[header_index+1]
            
            # Captures edge case where the first entity is not a section header
            if (row['Start'] < curr_header['Start']):
                continue
            
            # Adds the section header to the dataframe
            df.at[index,'Section_Header']= curr_header['Semantic']
            
            # Iterates
            if (row['Start'] >= next_header['Start']):
                header_index += 1
        
        # Set all remaining entities to final section
        else:
            df.at[index,'Section_Header']= curr_header['Semantic']
    
    #Combine specific headings into broad categories
    df['Section_Category'] = df['Section_Header'].map(specific_to_category_dict)

    return df

# %% [markdown]
# ## Remove unnecessary terms
#
# - Remove the entities that are under the categories: Allergy, Attestation, Instruction, Consent, Fam_Soc_Hx
# - Remove rows that do not have CUI's

# %%
def remove_unnecessary_terms(df):
    # Remove entities that are under specific categories
    unnecessary_categories = ['ALLERGY','ATTESTATION','INSTRUCTION','CONSENT','FAM_SOC_HX']
    index_to_remove = df[(df['Section_Category'].isin(unnecessary_categories))].index
#     print(' ------------------- Entities that are removed ---------------------------')
#     display(df.iloc[index_to_remove])
    df = df.drop(index_to_remove)
    
    # Remove rows that have null CUI's
    df = df.dropna(subset=['CUI'])
    df = df.reset_index(drop=True)
    return df

# %% [markdown]
# ## Clean Columns
# - Remove all the unnecessary information (RxNorm, Generic) from the CUI column
# - Fix blank assertion column- if they are blank, set as present

# %%
def clean_columns(df):
    #Create new column for RxNorm and Generic codes
    df = pd.concat([df, df['CUI'].str.split(',', expand=True)], axis=1)
    df.rename({0: "CUI_clean", 
               1: "RxNorm", 
               2: "Generic"}, 
              axis = "columns", inplace = True)
    
    for index, row in df.iterrows():
        # Some have RxNorm/Generic codes but not CUI codes
        if not (row['CUI_clean'] == 'null' or row['CUI_clean'].startswith('C')):
            value = row['CUI']
            df.at[index,'CUI_clean'] = "null"
            split = value.split(',')
            df.at[index,'RxNorm'] = split[0]
            df.at[index,'Generic'] = split[1]
    
        # Clean assertion column by setting all blank assertions to present (drugs are default present)
        if pd.isnull(row['Assertion']):
            df.at[index,'Assertion'] = "present"
    
    return df

# %% [markdown]
# # Main: Run the postprocessing pipeline

# %%
client = storage.Client()

blobs = client.list_blobs('stanfordoptimagroup', prefix="STRIDE/lowva/clampnoteoutput/")

print("Blobs:")

count = 0
num_rows = 0
for blob in blobs:
    if(count%100 == 0):
        print("Loading File Number: ", count)
        print("Loading File: ", blob.name)
    
    if(blob.name).endswith(".txt"):
        count += 1
        df = pd.read_csv('gs://stanfordoptimagroup/' + blob.name, delimiter = "\t", engine = "python", error_bad_lines = False, warn_bad_lines = True)
        df = extract_ids(blob.name, df)
        df = process_section_headers(df)
        df = remove_unnecessary_terms(df)
        df_processed = clean_columns(df)
        
        num_rows += df_processed.shape[0]
        
        #for first iteration, df_final does not exist
        if(count == 1):
            df_final = df_processed
            continue
        else:
            df_final = df_final.append(df_processed, ignore_index=True)
    else:
        print("............... File is not a text output and is skipped")

df_final.to_csv("clamp_output_postprocessing.csv", index=False)
# Out:
# Blobs:
# Loading File Number:  0
# Loading File:  STRIDE/lowva/clampnoteoutput/00003-pid1790-nid174426007.txt
# Loading File Number:  100
# Loading File:  STRIDE/lowva/clampnoteoutput/00486-pid56175-nid679279630.txt
# Loading File Number:  200
# Loading File:  STRIDE/lowva/clampnoteoutput/00917-pid81747-nid386388251.txt
# Loading File Number:  300
# Loading File:  STRIDE/lowva/clampnoteoutput/01196-pid93394-nid575209722.txt
# Loading File Number:  400
# Loading File:  STRIDE/lowva/clampnoteoutput/01538-pid110543-nid299035220.txt
# Skipping line 6: '	' expected after '"'
# Loading File Number:  500
# Loading File:  STRIDE/lowva/clampnoteoutput/02064-pid145293-nid82661986.txt
# Loading File Number:  600
# Loading File:  STRIDE/lowva/clampnoteoutput/02470-pid176150-nid734602488.txt
# Loading File Number:  700
# Loading File:  STRIDE/lowva/clampnoteoutput/02820-pid211787-nid115155499.txt
# Loading File Number:  800
# Loading File:  STRIDE/lowva/clampnoteoutput/03221-pid224319-nid376453471.txt
# Loading File Number:  900
# Loading File:  STRIDE/lowva/clampnoteoutput/03549-pid246050-nid516467866.txt
# Loading File Number:  1000
# Loading File:  STRIDE/lowva/clampnoteoutput/03902-pid259695-nid57417100.txt
# Loading File Number:  1100
# Loading File:  STRIDE/lowva/clampnoteoutput/04226-pid278693-nid346238080.txt
# Loading File Number:  1200
# Loading File:  STRIDE/lowva/clampnoteoutput/04562-pid296165-nid170205445.txt
# Loading File Number:  1300
# Loading File:  STRIDE/lowva/clampnoteoutput/05009-pid333803-nid208981295.txt
# Loading File Number:  1400
# Loading File:  STRIDE/lowva/clampnoteoutput/05427-pid353330-nid645714283.txt
# Loading File Number:  1500
# Loading File:  STRIDE/lowva/clampnoteoutput/05825-pid377799-nid73502754.txt
# Loading File Number:  1600
# Loading File:  STRIDE/lowva/clampnoteoutput/06176-pid397381-nid426652642.txt
# Skipping line 31: '	' expected after '"'
# Loading File Number:  1700
# Loading File:  STRIDE/lowva/clampnoteoutput/06587-pid413286-nid320109054.txt
# Loading File Number:  1800
# Loading File:  STRIDE/lowva/clampnoteoutput/06954-pid427022-nid63976067.txt
# Loading File Number:  1900
# Loading File:  STRIDE/lowva/clampnoteoutput/07512-pid444502-nid495896482.txt
# Loading File Number:  2000
# Loading File:  STRIDE/lowva/clampnoteoutput/07892-pid471731-nid73635060.txt
# Loading File Number:  2100
# Loading File:  STRIDE/lowva/clampnoteoutput/08286-pid492700-nid96878766.txt
# Loading File Number:  2200
# Loading File:  STRIDE/lowva/clampnoteoutput/08590-pid516531-nid101145861.txt
# Loading File Number:  2300
# Loading File:  STRIDE/lowva/clampnoteoutput/08926-pid520646-nid140615092.txt
# Loading File Number:  2400
# Loading File:  STRIDE/lowva/clampnoteoutput/09215-pid541535-nid267150618.txt
# Loading File Number:  2500
# Loading File:  STRIDE/lowva/clampnoteoutput/09619-pid573138-nid83386228.txt
# Loading File Number:  2600
# Loading File:  STRIDE/lowva/clampnoteoutput/09989-pid601753-nid747441966.txt
# Loading File Number:  2700
# Loading File:  STRIDE/lowva/clampnoteoutput/10359-pid633599-nid699530678.txt
# Loading File Number:  2800
# Loading File:  STRIDE/lowva/clampnoteoutput/10744-pid662845-nid207353757.txt
# Loading File Number:  2900
# Loading File:  STRIDE/lowva/clampnoteoutput/11162-pid697142-nid632739608.txt
# Loading File Number:  3000
# Loading File:  STRIDE/lowva/clampnoteoutput/11626-pid727381-nid715123890.txt
# Loading File Number:  3100
# Loading File:  STRIDE/lowva/clampnoteoutput/12052-pid759276-nid76863880.txt
# Loading File Number:  3200
# Loading File:  STRIDE/lowva/clampnoteoutput/12464-pid802399-nid80788063.txt
# Loading File Number:  3300
# Loading File:  STRIDE/lowva/clampnoteoutput/12888-pid828678-nid100102430.txt
# Loading File Number:  3400
# Loading File:  STRIDE/lowva/clampnoteoutput/13266-pid852358-nid272750118.txt
# Loading File Number:  3500
# Loading File:  STRIDE/lowva/clampnoteoutput/13613-pid880590-nid235349089.txt
# Loading File Number:  3600
# Loading File:  STRIDE/lowva/clampnoteoutput/14027-pid915275-nid262656344.txt
# Loading File Number:  3700
# Loading File:  STRIDE/lowva/clampnoteoutput/14356-pid939290-nid609904905.txt
# Loading File Number:  3800
# Loading File:  STRIDE/lowva/clampnoteoutput/14812-pid946586-nid339056444.txt
# Loading File Number:  3900
# Loading File:  STRIDE/lowva/clampnoteoutput/15122-pid959995-nid495832861.txt
# Loading File Number:  4000
# Loading File:  STRIDE/lowva/clampnoteoutput/15502-pid970349-nid162251291.txt
# Loading File Number:  4100
# Loading File:  STRIDE/lowva/clampnoteoutput/15795-pid983214-nid422903418.txt
# Loading File Number:  4200
# Loading File:  STRIDE/lowva/clampnoteoutput/16241-pid1017163-nid59763824.txt
# Loading File Number:  4300
# Loading File:  STRIDE/lowva/clampnoteoutput/16521-pid1038712-nid210083790.txt
# Loading File Number:  4400
# Loading File:  STRIDE/lowva/clampnoteoutput/16871-pid1050809-nid798485450.txt
# Loading File Number:  4500
# Loading File:  STRIDE/lowva/clampnoteoutput/17197-pid1079113-nid82414225.txt
# Loading File Number:  4600
# Loading File:  STRIDE/lowva/clampnoteoutput/17469-pid1099282-nid56328421.txt
# Loading File Number:  4700
# Loading File:  STRIDE/lowva/clampnoteoutput/17890-pid1125638-nid419857109.txt
# Loading File Number:  4800
# Loading File:  STRIDE/lowva/clampnoteoutput/18298-pid1146922-nid265808598.txt
# Loading File Number:  4900
# Loading File:  STRIDE/lowva/clampnoteoutput/18569-pid1168209-nid810995019.txt
# Loading File Number:  5000
# Loading File:  STRIDE/lowva/clampnoteoutput/19047-pid1198878-nid720697272.txt
# Loading File Number:  5100
# Loading File:  STRIDE/lowva/clampnoteoutput/19435-pid1221239-nid533789234.txt
# Loading File Number:  5200
# Loading File:  STRIDE/lowva/clampnoteoutput/19846-pid1245756-nid175226663.txt
# Loading File Number:  5300
# Loading File:  STRIDE/lowva/clampnoteoutput/20250-pid1263061-nid533650872.txt
# Loading File Number:  5400
# Loading File:  STRIDE/lowva/clampnoteoutput/20672-pid1279049-nid60068637.txt
# Loading File Number:  5500
# Loading File:  STRIDE/lowva/clampnoteoutput/21072-pid1309202-nid805204107.txt
# Loading File Number:  5600
# Loading File:  STRIDE/lowva/clampnoteoutput/21377-pid1330792-nid135557967.txt
# Loading File Number:  5700
# Loading File:  STRIDE/lowva/clampnoteoutput/21773-pid1360579-nid77398007.txt
# Loading File Number:  5800
# Loading File:  STRIDE/lowva/clampnoteoutput/22167-pid1380734-nid60191064.txt
# Skipping line 21: '	' expected after '"'
# Loading File Number:  5900
# Loading File:  STRIDE/lowva/clampnoteoutput/22519-pid1401541-nid118096328.txt
# Loading File Number:  6000
# Loading File:  STRIDE/lowva/clampnoteoutput/22987-pid1426251-nid159178460.txt
# Loading File Number:  6100
# Loading File:  STRIDE/lowva/clampnoteoutput/23357-pid1439363-nid264828810.txt
# Skipping line 2: unexpected end of data
# Loading File Number:  6200
# Loading File:  STRIDE/lowva/clampnoteoutput/23726-pid1459995-nid90331397.txt
# Loading File Number:  6300
# Loading File:  STRIDE/lowva/clampnoteoutput/24094-pid1472402-nid56513229.txt
# Loading File Number:  6400
# Loading File:  STRIDE/lowva/clampnoteoutput/24558-pid1515514-nid91221716.txt
# Loading File Number:  6500
# Loading File:  STRIDE/lowva/clampnoteoutput/24953-pid1532293-nid547718221.txt
# Loading File Number:  6600
# Loading File:  STRIDE/lowva/clampnoteoutput/25399-pid1554539-nid82024571.txt
# Loading File Number:  6700
# Loading File:  STRIDE/lowva/clampnoteoutput/25776-pid1583271-nid490472634.txt
# Loading File Number:  6800
# Loading File:  STRIDE/lowva/clampnoteoutput/26298-pid1607461-nid415490110.txt
# Loading File Number:  6900
# Loading File:  STRIDE/lowva/clampnoteoutput/26652-pid1624964-nid87406815.txt
# Loading File Number:  7000
# Loading File:  STRIDE/lowva/clampnoteoutput/27040-pid1642817-nid506994828.txt
# Loading File Number:  7100
# Loading File:  STRIDE/lowva/clampnoteoutput/27481-pid1658019-nid187444467.txt
# Loading File Number:  7200
# Loading File:  STRIDE/lowva/clampnoteoutput/27869-pid1682421-nid175046467.txt
# Loading File Number:  7300
# Loading File:  STRIDE/lowva/clampnoteoutput/28260-pid1711598-nid61574325.txt
# Loading File Number:  7400
# Loading File:  STRIDE/lowva/clampnoteoutput/28725-pid1723582-nid286533844.txt
# Loading File Number:  7500
# Loading File:  STRIDE/lowva/clampnoteoutput/28969-pid1731282-nid398605808.txt
# Loading File Number:  7600
# Loading File:  STRIDE/lowva/clampnoteoutput/29241-pid1740095-nid168280100.txt
# Loading File Number:  7700
# Loading File:  STRIDE/lowva/clampnoteoutput/29607-pid1754388-nid107606505.txt
# Loading File Number:  7800
# Loading File:  STRIDE/lowva/clampnoteoutput/29974-pid1777083-nid463240622.txt
# Loading File Number:  7900
# Loading File:  STRIDE/lowva/clampnoteoutput/30415-pid1807757-nid225431661.txt
# Loading File Number:  8000
# Loading File:  STRIDE/lowva/clampnoteoutput/30860-pid1833228-nid105319803.txt
# Loading File Number:  8100
# Loading File:  STRIDE/lowva/clampnoteoutput/31125-pid1842355-nid496899920.txt
# Loading File Number:  8200
# Loading File:  STRIDE/lowva/clampnoteoutput/31482-pid1858305-nid73782983.txt
# Loading File Number:  8300
# Loading File:  STRIDE/lowva/clampnoteoutput/31898-pid1870765-nid212347388.txt
# Loading File Number:  8400
# Loading File:  STRIDE/lowva/clampnoteoutput/32203-pid1893065-nid149448509.txt
# Loading File Number:  8500
# Loading File:  STRIDE/lowva/clampnoteoutput/32562-pid1913904-nid766092851.txt
# Loading File Number:  8600
# Loading File:  STRIDE/lowva/clampnoteoutput/32946-pid1930065-nid451961434.txt
# Loading File Number:  8700
# Loading File:  STRIDE/lowva/clampnoteoutput/33295-pid1945194-nid307102632.txt
# Loading File Number:  8800
# Loading File:  STRIDE/lowva/clampnoteoutput/33705-pid1964108-nid749689742.txt
# Loading File Number:  8900
# Loading File:  STRIDE/lowva/clampnoteoutput/34078-pid1987579-nid74676579.txt
# Loading File Number:  9000
# Loading File:  STRIDE/lowva/clampnoteoutput/34516-pid2021501-nid83187839.txt
# Loading File Number:  9100
# Loading File:  STRIDE/lowva/clampnoteoutput/34869-pid2034447-nid254316169.txt
# Loading File Number:  9200
# Loading File:  STRIDE/lowva/clampnoteoutput/35291-pid2068594-nid287243777.txt
# Loading File Number:  9300
# Loading File:  STRIDE/lowva/clampnoteoutput/35698-pid2078228-nid56488410.txt
# Loading File Number:  9400
# Loading File:  STRIDE/lowva/clampnoteoutput/35995-pid2093506-nid73222283.txt
# Loading File Number:  9500
# Loading File:  STRIDE/lowva/clampnoteoutput/36332-pid2114656-nid134720283.txt
# Loading File Number:  9600
# Loading File:  STRIDE/lowva/clampnoteoutput/36791-pid2141627-nid564930291.txt
# Skipping line 58: '	' expected after '"'
# Loading File Number:  9700
# Loading File:  STRIDE/lowva/clampnoteoutput/37220-pid2164115-nid360294578.txt
# Loading File Number:  9800
# Loading File:  STRIDE/lowva/clampnoteoutput/37711-pid2191575-nid66044167.txt
# Loading File Number:  9900
# Loading File:  STRIDE/lowva/clampnoteoutput/38039-pid2211936-nid581180657.txt
# Loading File Number:  10000
# Loading File:  STRIDE/lowva/clampnoteoutput/38332-pid2220192-nid608134431.txt
# Skipping line 28: unexpected end of data
# Loading File Number:  10100
# Loading File:  STRIDE/lowva/clampnoteoutput/38701-pid2244827-nid207698844.txt
# Loading File Number:  10200
# Loading File:  STRIDE/lowva/clampnoteoutput/38981-pid2255694-nid59229747.txt
# Loading File Number:  10300
# Loading File:  STRIDE/lowva/clampnoteoutput/39341-pid2263008-nid169428966.txt
# Loading File Number:  10400
# Loading File:  STRIDE/lowva/clampnoteoutput/39627-pid2276066-nid329839948.txt
# Loading File Number:  10500
# Loading File:  STRIDE/lowva/clampnoteoutput/39998-pid2301889-nid312183764.txt
# Loading File Number:  10600
# Loading File:  STRIDE/lowva/clampnoteoutput/40418-pid2309512-nid502713524.txt
# Loading File Number:  10700
# Loading File:  STRIDE/lowva/clampnoteoutput/40873-pid2339972-nid79700391.txt
# Loading File Number:  10800
# Loading File:  STRIDE/lowva/clampnoteoutput/41296-pid2350164-nid175836179.txt
# Loading File Number:  10900
# Loading File:  STRIDE/lowva/clampnoteoutput/41707-pid2357187-nid310699532.txt
# Loading File Number:  11000
# Loading File:  STRIDE/lowva/clampnoteoutput/42151-pid2401970-nid243760925.txt
# Loading File Number:  11100
# Loading File:  STRIDE/lowva/clampnoteoutput/42570-pid2425086-nid57233899.txt
# Loading File Number:  11200
# Loading File:  STRIDE/lowva/clampnoteoutput/42984-pid2454929-nid434093965.txt
# Loading File Number:  11300
# Loading File:  STRIDE/lowva/clampnoteoutput/43350-pid2469628-nid192992167.txt
# Loading File Number:  11400
# Loading File:  STRIDE/lowva/clampnoteoutput/43700-pid2481109-nid171507191.txt
# Loading File Number:  11500
# Loading File:  STRIDE/lowva/clampnoteoutput/44161-pid2506800-nid218574641.txt
# Loading File Number:  11600
# Loading File:  STRIDE/lowva/clampnoteoutput/44639-pid2520034-nid415360668.txt
# Loading File Number:  11700
# Loading File:  STRIDE/lowva/clampnoteoutput/44975-pid2552226-nid505241348.txt
# Loading File Number:  11800
# Loading File:  STRIDE/lowva/clampnoteoutput/45301-pid2579017-nid302444527.txt
# Loading File Number:  11900
# Loading File:  STRIDE/lowva/clampnoteoutput/45640-pid2597523-nid290706879.txt
# Loading File Number:  12000
# Loading File:  STRIDE/lowva/clampnoteoutput/45965-pid2630934-nid85683435.txt
# Loading File Number:  12100
# Loading File:  STRIDE/lowva/clampnoteoutput/46378-pid2649646-nid184603056.txt
# Loading File Number:  12200
# Loading File:  STRIDE/lowva/clampnoteoutput/46813-pid2671300-nid345494781.txt
# Loading File Number:  12300
# Loading File:  STRIDE/lowva/clampnoteoutput/47241-pid2706842-nid451957216.txt
# Loading File Number:  12400
# Loading File:  STRIDE/lowva/clampnoteoutput/47556-pid2744229-nid773580715.txt
# Loading File Number:  12500
# Loading File:  STRIDE/lowva/clampnoteoutput/48027-pid2784163-nid411484945.txt
# Loading File Number:  12600
# Loading File:  STRIDE/lowva/clampnoteoutput/48295-pid2801429-nid381861305.txt
# Loading File Number:  12700
# Loading File:  STRIDE/lowva/clampnoteoutput/48613-pid2807391-nid208401431.txt
# Loading File Number:  12800
# Loading File:  STRIDE/lowva/clampnoteoutput/48898-pid2824864-nid219707852.txt
# Loading File Number:  12900
# Loading File:  STRIDE/lowva/clampnoteoutput/49305-pid2850144-nid99769844.txt
# Loading File Number:  13000
# Loading File:  STRIDE/lowva/clampnoteoutput/49703-pid2876606-nid128206163.txt
# Loading File Number:  13100
# Loading File:  STRIDE/lowva/clampnoteoutput/50078-pid2883404-nid118458160.txt
# Loading File Number:  13200
# Loading File:  STRIDE/lowva/clampnoteoutput/50549-pid2920361-nid552465422.txt
# Loading File Number:  13300
# Loading File:  STRIDE/lowva/clampnoteoutput/50936-pid2935024-nid131607789.txt
# Loading File Number:  13400
# Loading File:  STRIDE/lowva/clampnoteoutput/51341-pid2953320-nid103736625.txt
# Loading File Number:  13500
# Loading File:  STRIDE/lowva/clampnoteoutput/51711-pid2966247-nid401862943.txt
# Loading File Number:  13600
# Loading File:  STRIDE/lowva/clampnoteoutput/52083-pid2992681-nid128602759.txt
# Loading File Number:  13700
# Loading File:  STRIDE/lowva/clampnoteoutput/52360-pid3002869-nid135046032.txt
# Loading File Number:  13800
# Loading File:  STRIDE/lowva/clampnoteoutput/52582-pid3005629-nid234239625.txt
# Loading File Number:  13900
# Loading File:  STRIDE/lowva/clampnoteoutput/52902-pid3015749-nid703764781.txt
# Loading File Number:  14000
# Loading File:  STRIDE/lowva/clampnoteoutput/53221-pid3032033-nid327547887.txt
# Loading File Number:  14100
# Loading File:  STRIDE/lowva/clampnoteoutput/53598-pid3061891-nid97120892.txt
# Loading File Number:  14200
# Loading File:  STRIDE/lowva/clampnoteoutput/53885-pid3085048-nid85242476.txt
# Loading File Number:  14300
# Loading File:  STRIDE/lowva/clampnoteoutput/54295-pid3121465-nid194629883.txt
# Loading File Number:  14400
# Loading File:  STRIDE/lowva/clampnoteoutput/54692-pid3143499-nid106689165.txt
# Skipping line 48: unexpected end of data
# Loading File Number:  14500
# Loading File:  STRIDE/lowva/clampnoteoutput/55127-pid3164800-nid62072539.txt
# Loading File Number:  14600
# Loading File:  STRIDE/lowva/clampnoteoutput/55476-pid3169722-nid419274090.txt
# Loading File Number:  14700
# Loading File:  STRIDE/lowva/clampnoteoutput/55860-pid3194675-nid593802012.txt
# Loading File Number:  14800
# Loading File:  STRIDE/lowva/clampnoteoutput/56263-pid3220298-nid694381056.txt
# Loading File Number:  14900
# Loading File:  STRIDE/lowva/clampnoteoutput/56750-pid3260791-nid392416602.txt
# Loading File Number:  15000
# Loading File:  STRIDE/lowva/clampnoteoutput/57034-pid3272371-nid96186883.txt
# Loading File Number:  15100
# Loading File:  STRIDE/lowva/clampnoteoutput/57399-pid3285956-nid242085143.txt
# Loading File Number:  15200
# Loading File:  STRIDE/lowva/clampnoteoutput/57701-pid3295247-nid69720719.txt
# Loading File Number:  15300
# Loading File:  STRIDE/lowva/clampnoteoutput/58121-pid3326703-nid228644003.txt
# Loading File Number:  15400
# Loading File:  STRIDE/lowva/clampnoteoutput/58558-pid3360097-nid328986406.txt
# Loading File Number:  15500
# Loading File:  STRIDE/lowva/clampnoteoutput/58887-pid3376073-nid57939270.txt
# Loading File Number:  15600
# Loading File:  STRIDE/lowva/clampnoteoutput/59220-pid3390652-nid154760488.txt
# Loading File Number:  15700
# Loading File:  STRIDE/lowva/clampnoteoutput/59571-pid3404316-nid771983210.txt
# Loading File Number:  15800
# Loading File:  STRIDE/lowva/clampnoteoutput/59987-pid3430137-nid77213035.txt
# Loading File Number:  15900
# Loading File:  STRIDE/lowva/clampnoteoutput/60364-pid3450552-nid233580719.txt
# Loading File Number:  16000
# Loading File:  STRIDE/lowva/clampnoteoutput/60719-pid3457182-nid338185188.txt
# Loading File Number:  16100
# Loading File:  STRIDE/lowva/clampnoteoutput/61071-pid3478527-nid616465171.txt
# Loading File Number:  16200
# Loading File:  STRIDE/lowva/clampnoteoutput/61520-pid3511359-nid796419939.txt
# Loading File Number:  16300
# Loading File:  STRIDE/lowva/clampnoteoutput/62053-pid3537682-nid319865172.txt
# Loading File Number:  16400
# Loading File:  STRIDE/lowva/clampnoteoutput/62453-pid3579491-nid147603572.txt
# Loading File Number:  16500
# Loading File:  STRIDE/lowva/clampnoteoutput/62795-pid3589553-nid164613856.txt
# Loading File Number:  16600
# Loading File:  STRIDE/lowva/clampnoteoutput/63138-pid3602888-nid431664143.txt
# Loading File Number:  16700
# Loading File:  STRIDE/lowva/clampnoteoutput/63532-pid3626995-nid178326930.txt
# Loading File Number:  16800
# Loading File:  STRIDE/lowva/clampnoteoutput/63925-pid3651841-nid65997487.txt
# Loading File Number:  16900
# Loading File:  STRIDE/lowva/clampnoteoutput/64284-pid3675169-nid147115929.txt
# Loading File Number:  17000
# Loading File:  STRIDE/lowva/clampnoteoutput/64625-pid3687499-nid103919770.txt
# Loading File Number:  17100
# Loading File:  STRIDE/lowva/clampnoteoutput/64975-pid3716264-nid88939279.txt
# Loading File Number:  17200
# Loading File:  STRIDE/lowva/clampnoteoutput/65384-pid3735475-nid160795311.txt
# Loading File Number:  17300
# Loading File:  STRIDE/lowva/clampnoteoutput/65894-pid3776792-nid82927360.txt
# Loading File Number:  17400
# Loading File:  STRIDE/lowva/clampnoteoutput/66275-pid3799819-nid190518575.txt
# Loading File Number:  17500
# Loading File:  STRIDE/lowva/clampnoteoutput/66657-pid3819245-nid57107158.txt
# Loading File Number:  17600
# Loading File:  STRIDE/lowva/clampnoteoutput/66994-pid3827515-nid481989815.txt
# Loading File Number:  17700
# Loading File:  STRIDE/lowva/clampnoteoutput/67276-pid3831673-nid468306961.txt
# Loading File Number:  17800
# Loading File:  STRIDE/lowva/clampnoteoutput/67661-pid3840966-nid426495570.txt

# %%
pd.set_option("max_rows", 20)
display(df_final)
print(num_rows)
# Out:
#             PID        NID Start   End   Semantic  \
# 0          1790  174426007   279   303       test
# 1          1790  174426007   329   361    problem
# 2          1790  174426007   366   375    problem
# 3          1790  174426007   442   471    problem
# 4          1790  174426007   508   521    problem
# ...         ...        ...   ...   ...        ...
# 882913  3843115  228200434  8612  8627  treatment
# 882914  3843115  228200434  8673  8691       drug
# 882915  3843115  228200434  8749  8756       drug
# 882916  3843115  228200434  8992  9001       drug
# 882917  3843115  228200434  9144  9166  treatment
#
#                                               CUI Assertion  \
# 0                                        C0154863   present
# 1                                        C0242383   present
# 2                                        C0086543   present
# 3                                        C0586742   present
# 4                                        C0743410    absent
# ...                                           ...       ...
# 882913                                   C0022209   present
# 882914  C0947644, RxNorm=[287524], Generic=[4603]   present
# 882915    C0004057, RxNorm=[1191], Generic=[1191]   present
# 882916      C0001927, RxNorm=[435], Generic=[435]   present
# 882917                                   C3476290   present
#
#                                   Entity       Section_Header  \
# 0               vitreoretinal evaluation                  HPI
# 1       age-related macular degeneration                  HPI
# 2                              cataracts                  HPI
# 3          increasing difficulty reading                  HPI
# 4                          acute changes                  HPI
# ...                                  ...                  ...
# 882913                   HANDIHALER INH)  CURRENT_MEDICATIONS
# 882914                furosemide (LASIX)  CURRENT_MEDICATIONS
# 882915                           aspirin  CURRENT_MEDICATIONS
# 882916                         albuterol  CURRENT_MEDICATIONS
# 882917            ophthalmic medications  CURRENT_MEDICATIONS
#
#        Section_Category CUI_clean            RxNorm          Generic
# 0                CC/HPI  C0154863              None             None
# 1                CC/HPI  C0242383              None             None
# 2                CC/HPI  C0086543              None             None
# 3                CC/HPI  C0586742              None             None
# 4                CC/HPI  C0743410              None             None
# ...                 ...       ...               ...              ...
# 882913       MEDICATION  C0022209              None             None
# 882914       MEDICATION  C0947644   RxNorm=[287524]   Generic=[4603]
# 882915       MEDICATION  C0004057     RxNorm=[1191]   Generic=[1191]
# 882916       MEDICATION  C0001927      RxNorm=[435]    Generic=[435]
# 882917       MEDICATION  C3476290              None             None
#
# [882918 rows x 13 columns]
# 882918
